# %% [markdown]
# # Mini Project: Tree-Based Algorithms

# %% [markdown]
# ## The "German Credit" Dataset

# %% [markdown]
# ### Dataset Details

# %% [markdown]
# This dataset has two classes (these would be considered labels in Machine Learning terms) to describe the worthiness of a personal loan: "Good" or "Bad". There are predictors related to attributes, such as: checking account status, duration, credit history, purpose of the loan, amount of the loan, savings accounts or bonds, employment duration, installment rate in percentage of disposable income, personal information, other debtors/guarantors, residence duration, property, age, other installment plans, housing, number of existing credits, job information, number of people being liable to provide maintenance for, telephone, and foreign worker status.
#
# Many of these predictors are discrete and have been expanded into several 0/1 indicator variables (a.k.a. they have been one-hot-encoded).
#
# This dataset has been kindly provided by Professor Dr. Hans Hofmann of the University of Hamburg, and can also be found on the UCI Machine Learning Repository.

# %% [markdown]
# ## Decision Trees

# %% [markdown]
#  As we have learned in the previous lectures, Decision Trees as a family of algorithms (irrespective to the particular implementation) are powerful algorithms that can produce models with a predictive accuracy higher than that produced by linear models, such as Linear or Logistic Regression. Primarily, this is due to the fact the DT's can model nonlinear relationships, and also have a number of tuning paramters, that allow for the practicioner to achieve the best possible model. An added bonus is the ability to visualize the trained Decision Tree model, which allows for some insight into how the model has produced the predictions that it has. One caveat here, to keep in mind, is that sometimes, due to the size of the dataset (both in the sense of the number of records, as well as the number of features), the visualization might prove to be very large and complex, increasing the difficulty of interpretation.

# %% [markdown]
# To give you a very good example of how Decision Trees can be visualized and interpreted, we would strongly recommend that, before continuing on with solving the problems in this Mini Project, you take the time to read this fanstastic, detailed and informative blog post: http://explained.ai/decision-tree-viz/index.html

# %% [markdown]
# ## Building Your First Decision Tree Model

# %% [markdown]
# So, now it's time to jump straight into the heart of the matter. Your first task, is to build a Decision Tree model, using the aforementioned "German Credit" dataset, which contains 1,000 records, and 62 columns (one of them presents the labels, and the other 61 present the potential features for the model.)

# %% [markdown]
# For this task, you will be using the scikit-learn library, which comes already pre-installed with the Anaconda Python distribution. In case you're not using that, you can easily install it using pip.

# %% [markdown]
# Before embarking on creating your first model, we would strongly encourage you to read the short tutorial for Decision Trees in scikit-learn (http://scikit-learn.org/stable/modules/tree.html), and then dive a bit deeper into the documentation of the algorithm itself (http://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeClassifier.html).

# %% [markdown]
# Also, since you want to be able to present the results of your model, we suggest you take a look at the tutorial for accuracy metrics for classification models (http://scikit-learn.org/stable/modules/model_evaluation.html#classification-report) as well as the more detailed documentation (http://scikit-learn.org/stable/modules/generated/sklearn.metrics.classification_report.html).
#
# Finally, an *amazing* resource that explains the various classification model accuracy metrics, as well as the relationships between them, can be found on Wikipedia: https://en.wikipedia.org/wiki/Confusion_matrix

# %% [markdown]
# (Note: as you've already learned in the Logistic Regression mini project, a standard practice in Machine Learning for achieving the best possible result when training a model is to use hyperparameter tuning, through Grid Search and k-fold Cross Validation. We strongly encourage you to use it here as well, not just because it's standard practice, but also becuase it's not going to be computationally to intensive, due to the size of the dataset that you're working with. Our suggestion here is that you split the data into 70% training, and 30% testing. Then, do the hyperparameter tuning and Cross Validation on the training set, and afterwards to a final test on the testing set.)

# %% [markdown]
# ### Now we pass the torch onto you! You can start building your first Decision Tree model! :)

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from pprint import pprint
from sklearn import preprocessing

# %%
! pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-2.0.0-cp310-cp310-macosx_10_9_x86_64.whl (11.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.7/11.7 MB 33.4 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: pytz>=2020.1 in /Users/austinpaxton/anaconda3/envs/ML_bootcamp/lib/python3.10/site-packages (from pandas) (2022.7)
# Collecting tzdata>=2022.1
#   Downloading tzdata-2023.3-py2.py3-none-any.whl (341 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.8/341.8 kB 19.9 MB/s eta 0:00:00
# Collecting numpy>=1.21.0
#   Downloading numpy-1.24.2-cp310-cp310-macosx_10_9_x86_64.whl (19.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.8/19.8 MB 36.3 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/austinpaxton/anaconda3/envs/ML_bootcamp/lib/python3.10/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in /Users/austinpaxton/anaconda3/envs/ML_bootcamp/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Installing collected packages: tzdata, numpy, pandas
# Successfully installed numpy-1.24.2 pandas-2.0.0 tzdata-2023.3

# %%
! pip install sklearn
# Out:
# Collecting sklearn
#   Using cached sklearn-0.0.post1.tar.gz (3.6 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: sklearn
#   Building wheel for sklearn (setup.py) ... done
#   Created wheel for sklearn: filename=sklearn-0.0.post1-py3-none-any.whl size=2935 sha256=6f027b3ace5a602ad56ebeed4f21deaa314c69293b58cf76f25f174285a443d7
#   Stored in directory: /Users/austinpaxton/Library/Caches/pip/wheels/c5/88/35/cc8a1e198b27a1d3d9d3f9b30090b9d5531778847835472ec4
# Successfully built sklearn
# Installing collected packages: sklearn
# Successfully installed sklearn-0.0.post1

# %%
! conda install scikit-learn --yes
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Users/austinpaxton/anaconda3/envs/ML_bootcamp
#
#   added / updated specs:
#     - scikit-learn
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     scikit-learn-1.2.2         |  py310hcec6c5f_0         7.1 MB
#     scipy-1.10.1               |  py310ha516a68_0        21.2 MB
#     ------------------------------------------------------------
#                                            Total:        28.2 MB
#
# The following NEW packages will be INSTALLED:
#
#   appdirs            pkgs/main/noarch::appdirs-1.4.4-pyhd3eb1b0_0
#   joblib             pkgs/main/osx-64::joblib-1.1.1-py310hecd8cb5_0
#   pooch              pkgs/main/noarch::pooch-1.4.0-pyhd3eb1b0_0
#   scikit-learn       pkgs/main/osx-64::scikit-learn-1.2.2-py310hcec6c5f_0
#   scipy              pkgs/main/osx-64::scipy-1.10.1-py310ha516a68_0
#   threadpoolctl      pkgs/main/noarch::threadpoolctl-2.2.0-pyh0d69192_0
#
#
#
# Downloading and Extracting Packages
# scikit-learn-1.2.2   | 7.1 MB    |                                       |   0%
# scikit-learn-1.2.2   | 7.1 MB    | #4                                    |   4%
# scikit-learn-1.2.2   | 7.1 MB    | ##############7                       |  40%
# scikit-learn-1.2.2   | 7.1 MB    | ##########################1           |  71%
# scipy-1.10.1         | 21.2 MB   | #######1                              |  19%
# scipy-1.10.1         | 21.2 MB   | ###########4                          |  31%
# scipy-1.10.1         | 21.2 MB   | ################1                     |  44%
# scipy-1.10.1         | 21.2 MB   | #######################1              |  63%
# scikit-learn-1.2.2   | 7.1 MB    | ##################################### | 100%
# scipy-1.10.1         | 21.2 MB   | ##################################### | 100%
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: -
#
#     Installed package of scikit-learn can be accelerated using scikit-learn-intelex.
#     More details are available here: https://intel.github.io/scikit-learn-intelex
#
#     For example:
#
#         $ conda install scikit-learn-intelex
#         $ python -m sklearnex my_application.py
#
#
#
# done

# %%
! conda install pandas --yes
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Users/austinpaxton/anaconda3/envs/ML_bootcamp
#
#   added / updated specs:
#     - pandas
#
#
# The following NEW packages will be INSTALLED:
#
#   blas               pkgs/main/osx-64::blas-1.0-openblas
#   bottleneck         pkgs/main/osx-64::bottleneck-1.3.5-py310h4e76f89_0
#   libgfortran        pkgs/main/osx-64::libgfortran-5.0.0-11_3_0_hecd8cb5_28
#   libgfortran5       pkgs/main/osx-64::libgfortran5-11.3.0-h9dfd629_28
#   libopenblas        pkgs/main/osx-64::libopenblas-0.3.21-h54e7dc3_0
#   llvm-openmp        pkgs/main/osx-64::llvm-openmp-14.0.6-h0dcd299_0
#   numexpr            pkgs/main/osx-64::numexpr-2.8.4-py310he50c29a_0
#   numpy              pkgs/main/osx-64::numpy-1.23.5-py310he50c29a_0
#   numpy-base         pkgs/main/osx-64::numpy-base-1.23.5-py310h992e150_0
#   pandas             pkgs/main/osx-64::pandas-1.5.3-py310h3ea8b11_0
#
#
#
# Downloading and Extracting Packages
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
# Your code here! :)
#import Data
data = pd.read_csv("GermanCredit.csv")
data.head()
data.describe()
data.info()  #no null values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 62 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Duration                                1000 non-null   int64
#  1   Amount                                  1000 non-null   int64
#  2   InstallmentRatePercentage               1000 non-null   int64
#  3   ResidenceDuration                       1000 non-null   int64
#  4   Age                                     1000 non-null   int64
#  5   NumberExistingCredits                   1000 non-null   int64
#  6   NumberPeopleMaintenance                 1000 non-null   int64
#  7   Telephone                               1000 non-null   int64
#  8   ForeignWorker                           1000 non-null   int64
#  9   Class                                   1000 non-null   object
#  10  CheckingAccountStatus.lt.0              1000 non-null   int64
#  11  CheckingAccountStatus.0.to.200          1000 non-null   int64
#  12  CheckingAccountStatus.gt.200            1000 non-null   int64
#  13  CheckingAccountStatus.none              1000 non-null   int64
#  14  CreditHistory.NoCredit.AllPaid          1000 non-null   int64
#  15  CreditHistory.ThisBank.AllPaid          1000 non-null   int64
#  16  CreditHistory.PaidDuly                  1000 non-null   int64
#  17  CreditHistory.Delay                     1000 non-null   int64
#  18  CreditHistory.Critical                  1000 non-null   int64
#  19  Purpose.NewCar                          1000 non-null   int64
#  20  Purpose.UsedCar                         1000 non-null   int64
#  21  Purpose.Furniture.Equipment             1000 non-null   int64
#  22  Purpose.Radio.Television                1000 non-null   int64
#  23  Purpose.DomesticAppliance               1000 non-null   int64
#  24  Purpose.Repairs                         1000 non-null   int64
#  25  Purpose.Education                       1000 non-null   int64
#  26  Purpose.Vacation                        1000 non-null   int64
#  27  Purpose.Retraining                      1000 non-null   int64
#  28  Purpose.Business                        1000 non-null   int64
#  29  Purpose.Other                           1000 non-null   int64
#  30  SavingsAccountBonds.lt.100              1000 non-null   int64
#  31  SavingsAccountBonds.100.to.500          1000 non-null   int64
#  32  SavingsAccountBonds.500.to.1000         1000 non-null   int64
#  33  SavingsAccountBonds.gt.1000             1000 non-null   int64
#  34  SavingsAccountBonds.Unknown             1000 non-null   int64
#  35  EmploymentDuration.lt.1                 1000 non-null   int64
#  36  EmploymentDuration.1.to.4               1000 non-null   int64
#  37  EmploymentDuration.4.to.7               1000 non-null   int64
#  38  EmploymentDuration.gt.7                 1000 non-null   int64
#  39  EmploymentDuration.Unemployed           1000 non-null   int64
#  40  Personal.Male.Divorced.Seperated        1000 non-null   int64
#  41  Personal.Female.NotSingle               1000 non-null   int64
#  42  Personal.Male.Single                    1000 non-null   int64
#  43  Personal.Male.Married.Widowed           1000 non-null   int64
#  44  Personal.Female.Single                  1000 non-null   int64
#  45  OtherDebtorsGuarantors.None             1000 non-null   int64
#  46  OtherDebtorsGuarantors.CoApplicant      1000 non-null   int64
#  47  OtherDebtorsGuarantors.Guarantor        1000 non-null   int64
#  48  Property.RealEstate                     1000 non-null   int64
#  49  Property.Insurance                      1000 non-null   int64
#  50  Property.CarOther                       1000 non-null   int64
#  51  Property.Unknown                        1000 non-null   int64
#  52  OtherInstallmentPlans.Bank              1000 non-null   int64
#  53  OtherInstallmentPlans.Stores            1000 non-null   int64
#  54  OtherInstallmentPlans.None              1000 non-null   int64
#  55  Housing.Rent                            1000 non-null   int64
#  56  Housing.Own                             1000 non-null   int64
#  57  Housing.ForFree                         1000 non-null   int64
#  58  Job.UnemployedUnskilled                 1000 non-null   int64
#  59  Job.UnskilledResident                   1000 non-null   int64
#  60  Job.SkilledEmployee                     1000 non-null   int64
#  61  Job.Management.SelfEmp.HighlyQualified  1000 non-null   int64
# dtypes: int64(61), object(1)
# memory usage: 484.5+ KB

# %%
#Split data into training and testing data
y = data.Class
y = y.map({"Good":1, "Bad":0})
X = data.drop("Class", axis=1)
print(f"X shape: {X.shape}")
print(f"y shape: {y.shape}")

X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.3, random_state=7)
print(X_train.shape)
print(y_train.shape)
# Out:
# X shape: (1000, 61)
# y shape: (1000,)
# (700, 61)
# (700,)

# %%
tree_model = DecisionTreeClassifier()
params = {"splitter": ("best", "random"),
         "max_depth": list(range(2,50,5)),
         "min_samples_leaf": list(range(1,5)),
         "max_features": list(range(1,61,1)),
         }
clf =  GridSearchCV(tree_model, params)
clf.fit(X_train,y_train)
print(clf.best_params_)
print(clf.best_score_)
# Out:
# {'max_depth': 2, 'max_features': 38, 'min_samples_leaf': 1, 'splitter': 'random'}
# 0.7300000000000001

# %%
#evaluate best params on test set

y_pred = clf.predict(X_test)
pprint(classification_report(y_test, y_pred))
# Out:
# ('              precision    recall  f1-score   support\n'
#  '\n'
#  '           0       0.47      0.46      0.47        83\n'
#  '           1       0.80      0.81      0.80       217\n'
#  '\n'
#  '    accuracy                           0.71       300\n'
#  '   macro avg       0.64      0.63      0.63       300\n'
#  'weighted avg       0.71      0.71      0.71       300\n')

# %% [markdown]
# High recall 0.9 (TP/(TP+FN)) for good class means that not a lot of false negatives (falsely categorizing good as bad) are occuring. Also, good has high precision (TP/(TP+FP)) which means that when it predicts a creditor as good class it is correct 77% of the time.  The model is more likely to falsely predict the class as good than falsely predict the class as bad. This can be problematic because the user would want to spot a bad creditor at the expense of looking into people who were miosclassfied as bad.
#
# The bad class has a lower recal than precision which means that it is more likely to incorrectly classify a bad class as good than incorrectly classify a good class as bad.

# %% [markdown]
# ### After you've built the best model you can, now it's time to visualize it!

# %% [markdown]
# Rememeber that amazing blog post from a few paragraphs ago, that demonstrated how to visualize and interpret the results of your Decision Tree model. We've seen that this can perform very well, but let's see how it does on the "German Credit" dataset that we're working on, due to it being a bit larger than the one used by the blog authors.

# %% [markdown]
# First, we're going to need to install their package. If you're using Anaconda, this can be done easily by running:

# %%
! pip install dtreeviz
# Out:
# Collecting dtreeviz
#   Using cached dtreeviz-2.2.0-py3-none-any.whl (90 kB)
# Requirement already satisfied: scikit-learn in /Users/austinpaxton/anaconda3/envs/ML_bootcamp/lib/python3.10/site-packages (from dtreeviz) (1.2.2)
# Collecting matplotlib
#   Downloading matplotlib-3.7.1-cp310-cp310-macosx_10_12_x86_64.whl (7.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 10.9 MB/s eta 0:00:0000:0100:01
# Collecting colour
#   Using cached colour-0.1.5-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: pandas in /Users/austinpaxton/anaconda3/envs/ML_bootcamp/lib/python3.10/site-packages (from dtreeviz) (2.0.0)
# Requirement already satisfied: numpy in /Users/austinpaxton/anaconda3/envs/ML_bootcamp/lib/python3.10/site-packages (from dtreeviz) (1.24.2)
# Collecting pytest
#   Downloading pytest-7.2.2-py3-none-any.whl (317 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.2/317.2 kB 19.0 MB/s eta 0:00:00
# Collecting graphviz>=0.9
#   Using cached graphviz-0.20.1-py3-none-any.whl (47 kB)
# Collecting pillow>=6.2.0
#   Downloading Pillow-9.5.0-cp310-cp310-macosx_10_10_x86_64.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 38.7 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: python-dateutil>=2.7 in /Users/austinpaxton/anaconda3/envs/ML_bootcamp/lib/python3.10/site-packages (from matplotlib->dtreeviz) (2.8.2)
# Collecting cycler>=0.10
#   Downloading cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.4.4-cp310-cp310-macosx_10_9_x86_64.whl (65 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.5/65.5 kB 7.7 MB/s eta 0:00:00
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.39.3-py3-none-any.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 30.3 MB/s eta 0:00:00
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.0.7-cp310-cp310-macosx_10_9_x86_64.whl (244 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.2/244.2 kB 17.8 MB/s eta 0:00:00
# Collecting pyparsing>=2.3.1
#   Downloading pyparsing-3.0.9-py3-none-any.whl (98 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.3/98.3 kB 12.0 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.0 in /Users/austinpaxton/anaconda3/envs/ML_bootcamp/lib/python3.10/site-packages (from matplotlib->dtreeviz) (23.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/austinpaxton/anaconda3/envs/ML_bootcamp/lib/python3.10/site-packages (from pandas->dtreeviz) (2022.7)
# Requirement already satisfied: tzdata>=2022.1 in /Users/austinpaxton/anaconda3/envs/ML_bootcamp/lib/python3.10/site-packages (from pandas->dtreeviz) (2023.3)
# Requirement already satisfied: attrs>=19.2.0 in /Users/austinpaxton/anaconda3/envs/ML_bootcamp/lib/python3.10/site-packages (from pytest->dtreeviz) (22.1.0)
# Requirement already satisfied: tomli>=1.0.0 in /Users/austinpaxton/anaconda3/envs/ML_bootcamp/lib/python3.10/site-packages (from pytest->dtreeviz) (2.0.1)
# Collecting exceptiongroup>=1.0.0rc8
#   Downloading exceptiongroup-1.1.1-py3-none-any.whl (14 kB)
# Collecting pluggy<2.0,>=0.12
#   Downloading pluggy-1.0.0-py2.py3-none-any.whl (13 kB)
# Collecting iniconfig
#   Downloading iniconfig-2.0.0-py3-none-any.whl (5.9 kB)
# Requirement already satisfied: joblib>=1.1.1 in /Users/austinpaxton/anaconda3/envs/ML_bootcamp/lib/python3.10/site-packages (from scikit-learn->dtreeviz) (1.1.1)
# Requirement already satisfied: scipy>=1.3.2 in /Users/austinpaxton/anaconda3/envs/ML_bootcamp/lib/python3.10/site-packages (from scikit-learn->dtreeviz) (1.10.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/austinpaxton/anaconda3/envs/ML_bootcamp/lib/python3.10/site-packages (from scikit-learn->dtreeviz) (2.2.0)
# Requirement already satisfied: six>=1.5 in /Users/austinpaxton/anaconda3/envs/ML_bootcamp/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib->dtreeviz) (1.16.0)
# Installing collected packages: colour, pyparsing, pluggy, pillow, kiwisolver, iniconfig, graphviz, fonttools, exceptiongroup, cycler, contourpy, pytest, matplotlib, dtreeviz
# Successfully installed colour-0.1.5 contourpy-1.0.7 cycler-0.11.0 dtreeviz-2.2.0 exceptiongroup-1.1.1 fonttools-4.39.3 graphviz-0.20.1 iniconfig-2.0.0 kiwisolver-1.4.4 matplotlib-3.7.1 pillow-9.5.0 pluggy-1.0.0 pyparsing-3.0.9 pytest-7.2.2

# %% [markdown]
# If for any reason this way of installing doesn't work for you straight out of the box, please refer to the more detailed documentation here: https://github.com/parrt/dtreeviz

# %% [markdown]
# Now you're ready to visualize your Decision Tree model! Please feel free to use the blog post for guidance and inspiration!

# %%
from sklearn import tree
import graphviz

# %%
tuned_tree = DecisionTreeClassifier(max_depth=2,max_features=54,min_samples_leaf=1,splitter='random')
tuned_tree.fit(X_train,y_train)

y_pred = tuned_tree.predict(X_test)

tree_accuracy = accuracy_score(y_test, y_pred)
print(tree_accuracy)

tree.plot_tree(tuned_tree) #try plotting w matplotlib
# Out:
# 0.7133333333333334
# [Text(0.5, 0.8333333333333334, 'x[12] <= 0.257\ngini = 0.428\nsamples = 700\nvalue = [217, 483]'),
#  Text(0.25, 0.5, 'x[50] <= 0.021\ngini = 0.491\nsamples = 422\nvalue = [182, 240]'),
#  Text(0.125, 0.16666666666666666, 'gini = 0.474\nsamples = 347\nvalue = [134, 213]'),
#  Text(0.375, 0.16666666666666666, 'gini = 0.461\nsamples = 75\nvalue = [48, 27]'),
#  Text(0.75, 0.5, 'x[53] <= 0.856\ngini = 0.22\nsamples = 278\nvalue = [35, 243]'),
#  Text(0.625, 0.16666666666666666, 'gini = 0.425\nsamples = 49\nvalue = [15, 34]'),
#  Text(0.875, 0.16666666666666666, 'gini = 0.159\nsamples = 229\nvalue = [20, 209]')]

# %%
# Your code here! :
# %matplotlib inline
import dtreeviz

tuned_tree = DecisionTreeClassifier(max_depth=2,max_features=54,min_samples_leaf=1,splitter='random')
tuned_tree.fit(X_train,y_train)

viz_model = dtreeviz.model(tuned_tree, 
                           X_train, 
                           y_train, 
                           feature_names=list(X_train.columns), 
                           target_name='Class',
                           class_names = ["1", "0"]
                          )
viz_model

# %%
#try graphviz bc dtreeviz is not working

tree_graph = tree.export_graphviz(tuned_tree, out_file=None,feature_names=X_train.columns)
graphviz.Source(tree_graph)

# %% [markdown]
# ## Random Forests

# %% [markdown]
# As discussed in the lecture videos, Decision Tree algorithms also have certain undesireable properties. Mainly the have low bias, which is good, but tend to have high variance - which is *not* so good (more about this problem here: https://en.wikipedia.org/wiki/Bias%E2%80%93variance_tradeoff).

# %% [markdown]
# Noticing these problems, the late Professor Leo Breiman, in 2001, developed the Random Forests algorithm, which mitigates these problems, while at the same time providing even higher predictive accuracy than the majority of Decision Tree algorithm implementations. While the curriculum contains two excellent lectures on Random Forests, if you're interested, you can dive into the original paper here: https://link.springer.com/content/pdf/10.1023%2FA%3A1010933404324.pdf.

# %% [markdown]
# In the next part of this assignment, your are going to use the same "German Credit" dataset to train, tune, and measure the performance of a Random Forests model. You will also see certain functionalities that this model, even though it's a bit of a "black box", provides for some degree of interpretability.

# %% [markdown]
# First, let's build a Random Forests model, using the same best practices that you've used for your Decision Trees model. You can reuse the things you've already imported there, so no need to do any re-imports, new train/test splits, or loading up the data again.

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
# Your code here! :)
rfc = RandomForestClassifier()
params = {"n_estimators": list(range(50,300,10))}
rfc_search = GridSearchCV(rfc,params)
rfc_search.fit(X_train,y_train)
print(rfc_search.best_params_)
print(rfc_search.best_score_)
# Out:
# {'n_estimators': 230}
# 0.7485714285714286

# %%
rfc_model = RandomForestClassifier(n_estimators=260)
rfc_model.fit(X_train,y_train)
y_pred = rfc_model.predict(X_test)
rfc_accuracy = accuracy_score(y_test,y_pred)
print(rfc_accuracy)
# Out:
# 0.7966666666666666

# %% [markdown]
# As mentioned, there are certain ways to "peek" into a model created by the Random Forests algorithm. The first, and most popular one, is the Feature Importance calculation functionality. This allows the ML practitioner to see an ordering of the importance of the features that have contributed the most to the predictive accuracy of the model.
#
# You can see how to use this in the scikit-learn documentation (http://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestClassifier.html#sklearn.ensemble.RandomForestClassifier.feature_importances_). Now, if you tried this, you would just get an ordered table of not directly interpretable numeric values. Thus, it's much more useful to show the feature importance in a visual way. You can see an example of how that's done here: http://scikit-learn.org/stable/auto_examples/ensemble/plot_forest_importances.html#sphx-glr-auto-examples-ensemble-plot-forest-importances-py
#
# Now you try! Let's visualize the importance of features from your Random Forests model!

# %%
# Your code here
import numpy as np
import matplotlib.pyplot as plt

importances = rfc_model.feature_importances_
std = np.std([tree.feature_importances_ for tree in rfc_model.estimators_], axis=0)


feature_names = list(X_train.columns)
forest_importances = pd.Series(importances, index=feature_names)
fig, ax = plt.subplots()
forest_importances.plot.bar(yerr=std, ax=ax)
ax.set_title("Feature importances using MDI")
ax.set_ylabel("Mean decrease in impurity")

fig.set_figheight(15)
fig.set_figwidth(15)
#fig.subplots_adjust()
#fig.tight_layout()

# %% [markdown]
# A final method for gaining some insight into the inner working of your Random Forests models is a so-called Partial Dependence Plot. The Partial Dependence Plot (PDP or PD plot) shows the marginal effect of a feature on the predicted outcome of a previously fit model. The prediction function is fixed at a few values of the chosen features and averaged over the other features. A partial dependence plot can show if the relationship between the target and a feature is linear, monotonic or more complex.
#
# In scikit-learn, PDPs are implemented and available for certain algorithms, but at this point (version 0.20.0) they are not yet implemented for Random Forests. Thankfully, there is an add-on package called **PDPbox** (https://pdpbox.readthedocs.io/en/latest/) which adds this functionality to Random Forests. The package is easy to install through pip.

# %%
! pip install pdpbox

# %% [markdown]
# While we encourage you to read the documentation for the package (and reading package documentation in general is a good habit to develop), the authors of the package have also written an excellent blog post on how to use it, showing examples on different algorithms from scikit-learn (the Random Forests example is towards the end of the blog post): https://briangriner.github.io/Partial_Dependence_Plots_presentation-BrianGriner-PrincetonPublicLibrary-4.14.18-updated-4.22.18.html

# %% [markdown]
# So, armed with this new knowledge, feel free to pick a few features, and make a couple of Partial Dependence Plots of your own!

# %%
#blog link not working

# %%
# Your code here!
import pdpbox
from sklearn.inspection import partial_dependence, PartialDependenceDisplay
features= [0,(0,1)]

#PartialDependenceDisplay.from_estimator(rfc_model, X_train, features)
PartialDependenceDisplay.from_estimator(rfc_model, X_train, features)

# %% [markdown]
# ## (Optional) Advanced Boosting-Based Algorithms

# %% [markdown]
# As explained in the video lectures, the next generation of algorithms after Random Forests (that use Bagging, a.k.a. Bootstrap Aggregation) were developed using Boosting, and the first one of these were Gradient Boosted Machines, which are implemented in scikit-learn (http://scikit-learn.org/stable/modules/ensemble.html#gradient-tree-boosting).

# %% [markdown]
# Still, in recent years, a number of variations on GBMs have been developed by different research amd industry groups, all of them bringing improvements, both in speed, accuracy and functionality to the original Gradient Boosting algorithms.
#
# In no order of preference, these are:
# 1. **XGBoost**: https://xgboost.readthedocs.io/en/latest/
# 2. **CatBoost**: https://tech.yandex.com/catboost/
# 3. **LightGBM**: https://lightgbm.readthedocs.io/en/latest/

# %% [markdown]
# If you're using the Anaconda distribution, these are all very easy to install:

# %%
! conda install -c anaconda py-xgboost --yes
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Users/austinpaxton/anaconda3/envs/ML_bootcamp
#
#   added / updated specs:
#     - py-xgboost
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _py-xgboost-mutex-2.0      |            cpu_0           8 KB  anaconda
#     ca-certificates-2022.4.26  |       hecd8cb5_0         132 KB  anaconda
#     certifi-2022.6.15          |  py310hecd8cb5_0         157 KB  anaconda
#     libxgboost-1.5.0           |       he9d5cce_1         2.2 MB  anaconda
#     py-xgboost-1.5.0           |  py310hecd8cb5_1         155 KB  anaconda
#     ------------------------------------------------------------
#                                            Total:         2.7 MB
#
# The following NEW packages will be INSTALLED:
#
#   _py-xgboost-mutex  anaconda/osx-64::_py-xgboost-mutex-2.0-cpu_0
#   libxgboost         anaconda/osx-64::libxgboost-1.5.0-he9d5cce_1
#   py-xgboost         anaconda/osx-64::py-xgboost-1.5.0-py310hecd8cb5_1
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   ca-certificates    conda-forge::ca-certificates-2022.12.~ --> anaconda::ca-certificates-2022.4.26-hecd8cb5_0
#   certifi            conda-forge/noarch::certifi-2022.12.7~ --> anaconda/osx-64::certifi-2022.6.15-py310hecd8cb5_0
#   openssl            conda-forge::openssl-1.1.1t-hfd90126_0 --> pkgs/main::openssl-1.1.1t-hca72f7f_0
#
#
#
# Downloading and Extracting Packages
# certifi-2022.6.15    | 157 KB    |                                       |   0%
# libxgboost-1.5.0     | 2.2 MB    |                                       |   0%
#
# py-xgboost-1.5.0     | 155 KB    |                                       |   0%
#
#
# ca-certificates-2022 | 132 KB    |                                       |   0%
#
#
#
# certifi-2022.6.15    | 157 KB    | ###7                                  |  10%
# libxgboost-1.5.0     | 2.2 MB    | 2                                     |   1%
#
#
# ca-certificates-2022 | 132 KB    | ####4                                 |  12%
#
#
#
# _py-xgboost-mutex-2. | 8 KB      | ##################################### | 100%
#
#
#
# _py-xgboost-mutex-2. | 8 KB      | ##################################### | 100%
#
# py-xgboost-1.5.0     | 155 KB    | ###8                                  |  10%
#
#
# certifi-2022.6.15    | 157 KB    | ##################################### | 100%
# libxgboost-1.5.0     | 2.2 MB    | #########3                            |  25%
#
# py-xgboost-1.5.0     | 155 KB    | ##################################### | 100%
# libxgboost-1.5.0     | 2.2 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
! conda install -c conda-forge catboost --yes
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Users/austinpaxton/anaconda3/envs/ML_bootcamp
#
#   added / updated specs:
#     - catboost
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     brotli-1.0.9               |       hb7f2c08_8          19 KB  conda-forge
#     brotli-bin-1.0.9           |       hb7f2c08_8          17 KB  conda-forge
#     ca-certificates-2022.12.7  |       h033912b_0         142 KB  conda-forge
#     cairo-1.16.0               |       h3ce6f7e_4        1011 KB
#     catboost-1.1.1             |  py310h2ec42d9_2        15.4 MB  conda-forge
#     certifi-2022.12.7          |     pyhd8ed1ab_0         147 KB  conda-forge
#     cycler-0.11.0              |     pyhd8ed1ab_0          10 KB  conda-forge
#     expat-2.5.0                |       hf0c8a7f_1         118 KB  conda-forge
#     font-ttf-dejavu-sans-mono-2.37|       hab24e00_0         388 KB  conda-forge
#     font-ttf-inconsolata-3.000 |       h77eed37_0          94 KB  conda-forge
#     font-ttf-source-code-pro-2.038|       h77eed37_0         684 KB  conda-forge
#     font-ttf-ubuntu-0.83       |       hab24e00_0         1.9 MB  conda-forge
#     fontconfig-2.14.1          |       hb0a0c50_2         249 KB
#     fonts-conda-ecosystem-1    |                0           4 KB  conda-forge
#     fonts-conda-forge-1        |                0           4 KB  conda-forge
#     fonttools-4.39.3           |  py310h90acd4f_0         2.0 MB  conda-forge
#     freetype-2.10.4            |       h4cff582_1         890 KB  conda-forge
#     fribidi-1.0.10             |       hbcb3906_0          64 KB  conda-forge
#     gdk-pixbuf-2.42.10         |       h6c40b1e_0         580 KB
#     gettext-0.21.0             |       he85b6c0_1         3.0 MB
#     giflib-5.2.1               |       hb7f2c08_3          75 KB  conda-forge
#     graphite2-1.3.14           |       he9d5cce_1          82 KB
#     graphviz-2.50.0            |       h196fa6a_0         2.4 MB
#     gts-0.7.6                  |       h2684ab5_0         341 KB  conda-forge
#     harfbuzz-4.3.0             |       hffc734d_1         1.2 MB
#     jpeg-9e                    |       hb7f2c08_3         226 KB  conda-forge
#     kiwisolver-1.4.4           |  py310ha23aa8a_1          63 KB  conda-forge
#     lcms2-2.15                 |       h29502cd_0         222 KB  conda-forge
#     libbrotlicommon-1.0.9      |       hb7f2c08_8          64 KB  conda-forge
#     libbrotlidec-1.0.9         |       hb7f2c08_8          33 KB  conda-forge
#     libbrotlienc-1.0.9         |       hb7f2c08_8         303 KB  conda-forge
#     libdeflate-1.17            |       hac1461d_0          66 KB  conda-forge
#     libexpat-2.5.0             |       hf0c8a7f_1          68 KB  conda-forge
#     libgd-2.3.3                |       hcec6c5f_2         221 KB
#     librsvg-2.54.4             |       h2f8da11_3         6.5 MB
#     libtool-2.4.7              |       hf0c8a7f_0         398 KB  conda-forge
#     libwebp-1.2.4              |       h70a068d_1          76 KB  conda-forge
#     lz4-c-1.9.4                |       hf0c8a7f_0         153 KB  conda-forge
#     matplotlib-base-3.5.3      |  py310h6438751_0         7.4 MB  conda-forge
#     munkres-1.1.4              |     pyh9f0ad1d_0          12 KB  conda-forge
#     openssl-1.1.1t             |       hfd90126_0         1.7 MB  conda-forge
#     pango-1.50.7               |       h80fe9ab_0         523 KB
#     pcre-8.45                  |       he49afe7_0         220 KB  conda-forge
#     pixman-0.40.0              |       hbcb3906_0         615 KB  conda-forge
#     plotly-5.14.1              |     pyhd8ed1ab_0         4.9 MB  conda-forge
#     pyparsing-3.0.9            |     pyhd8ed1ab_0          79 KB  conda-forge
#     python-graphviz-0.20.1     |     pyh22cad53_0          35 KB  conda-forge
#     python_abi-3.10            |          2_cp310           4 KB  conda-forge
#     tenacity-8.2.2             |     pyhd8ed1ab_0          22 KB  conda-forge
#     unicodedata2-15.0.0        |  py310h90acd4f_0         486 KB  conda-forge
#     zstd-1.5.4                 |       hc035e20_0         591 KB
#     ------------------------------------------------------------
#                                            Total:        55.5 MB
#
# The following NEW packages will be INSTALLED:
#
#   brotli             conda-forge/osx-64::brotli-1.0.9-hb7f2c08_8
#   brotli-bin         conda-forge/osx-64::brotli-bin-1.0.9-hb7f2c08_8
#   cairo              pkgs/main/osx-64::cairo-1.16.0-h3ce6f7e_4
#   catboost           conda-forge/osx-64::catboost-1.1.1-py310h2ec42d9_2
#   cycler             conda-forge/noarch::cycler-0.11.0-pyhd8ed1ab_0
#   expat              conda-forge/osx-64::expat-2.5.0-hf0c8a7f_1
#   font-ttf-dejavu-s~ conda-forge/noarch::font-ttf-dejavu-sans-mono-2.37-hab24e00_0
#   font-ttf-inconsol~ conda-forge/noarch::font-ttf-inconsolata-3.000-h77eed37_0
#   font-ttf-source-c~ conda-forge/noarch::font-ttf-source-code-pro-2.038-h77eed37_0
#   font-ttf-ubuntu    conda-forge/noarch::font-ttf-ubuntu-0.83-hab24e00_0
#   fontconfig         pkgs/main/osx-64::fontconfig-2.14.1-hb0a0c50_2
#   fonts-conda-ecosy~ conda-forge/noarch::fonts-conda-ecosystem-1-0
#   fonts-conda-forge  conda-forge/noarch::fonts-conda-forge-1-0
#   fonttools          conda-forge/osx-64::fonttools-4.39.3-py310h90acd4f_0
#   freetype           conda-forge/osx-64::freetype-2.10.4-h4cff582_1
#   fribidi            conda-forge/osx-64::fribidi-1.0.10-hbcb3906_0
#   gdk-pixbuf         pkgs/main/osx-64::gdk-pixbuf-2.42.10-h6c40b1e_0
#   gettext            pkgs/main/osx-64::gettext-0.21.0-he85b6c0_1
#   giflib             conda-forge/osx-64::giflib-5.2.1-hb7f2c08_3
#   glib               pkgs/main/osx-64::glib-2.69.1-hfff2838_2
#   graphite2          pkgs/main/osx-64::graphite2-1.3.14-he9d5cce_1
#   graphviz           pkgs/main/osx-64::graphviz-2.50.0-h196fa6a_0
#   gts                conda-forge/osx-64::gts-0.7.6-h2684ab5_0
#   harfbuzz           pkgs/main/osx-64::harfbuzz-4.3.0-hffc734d_1
#   jpeg               conda-forge/osx-64::jpeg-9e-hb7f2c08_3
#   kiwisolver         conda-forge/osx-64::kiwisolver-1.4.4-py310ha23aa8a_1
#   lcms2              conda-forge/osx-64::lcms2-2.15-h29502cd_0
#   lerc               pkgs/main/osx-64::lerc-3.0-he9d5cce_0
#   libbrotlicommon    conda-forge/osx-64::libbrotlicommon-1.0.9-hb7f2c08_8
#   libbrotlidec       conda-forge/osx-64::libbrotlidec-1.0.9-hb7f2c08_8
#   libbrotlienc       conda-forge/osx-64::libbrotlienc-1.0.9-hb7f2c08_8
#   libdeflate         conda-forge/osx-64::libdeflate-1.17-hac1461d_0
#   libexpat           conda-forge/osx-64::libexpat-2.5.0-hf0c8a7f_1
#   libgd              pkgs/main/osx-64::libgd-2.3.3-hcec6c5f_2
#   libpng             pkgs/main/osx-64::libpng-1.6.39-h6c40b1e_0
#   librsvg            pkgs/main/osx-64::librsvg-2.54.4-h2f8da11_3
#   libtiff            pkgs/main/osx-64::libtiff-4.5.0-hcec6c5f_2
#   libtool            conda-forge/osx-64::libtool-2.4.7-hf0c8a7f_0
#   libwebp            conda-forge/osx-64::libwebp-1.2.4-h70a068d_1
#   libwebp-base       pkgs/main/osx-64::libwebp-base-1.2.4-h6c40b1e_1
#   lz4-c              conda-forge/osx-64::lz4-c-1.9.4-hf0c8a7f_0
#   matplotlib-base    conda-forge/osx-64::matplotlib-base-3.5.3-py310h6438751_0
#   munkres            conda-forge/noarch::munkres-1.1.4-pyh9f0ad1d_0
#   pango              pkgs/main/osx-64::pango-1.50.7-h80fe9ab_0
#   pcre               conda-forge/osx-64::pcre-8.45-he49afe7_0
#   pillow             pkgs/main/osx-64::pillow-9.4.0-py310hcec6c5f_0
#   pixman             conda-forge/osx-64::pixman-0.40.0-hbcb3906_0
#   plotly             conda-forge/noarch::plotly-5.14.1-pyhd8ed1ab_0
#   pyparsing          conda-forge/noarch::pyparsing-3.0.9-pyhd8ed1ab_0
#   python-graphviz    conda-forge/noarch::python-graphviz-0.20.1-pyh22cad53_0
#   python_abi         conda-forge/osx-64::python_abi-3.10-2_cp310
#   tenacity           conda-forge/noarch::tenacity-8.2.2-pyhd8ed1ab_0
#   unicodedata2       conda-forge/osx-64::unicodedata2-15.0.0-py310h90acd4f_0
#   zstd               pkgs/main/osx-64::zstd-1.5.4-hc035e20_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   ca-certificates    pkgs/main::ca-certificates-2023.01.10~ --> conda-forge::ca-certificates-2022.12.7-h033912b_0
#   certifi            pkgs/main/osx-64::certifi-2022.12.7-p~ --> conda-forge/noarch::certifi-2022.12.7-pyhd8ed1ab_0
#   openssl              pkgs/main::openssl-1.1.1t-hca72f7f_0 --> conda-forge::openssl-1.1.1t-hfd90126_0
#
#
#
# Downloading and Extracting Packages
# giflib-5.2.1         | 75 KB     |                                       |   0%
# freetype-2.10.4      | 890 KB    |                                       |   0%
#
# ca-certificates-2022 | 142 KB    |                                       |   0%
#
#
# lz4-c-1.9.4          | 153 KB    |                                       |   0%
#
#
#
# gettext-0.21.0       | 3.0 MB    |                                       |   0%
#
#
#
#
# libgd-2.3.3          | 221 KB    |                                       |   0%
#
#
#
#
#
# munkres-1.1.4        | 12 KB     |                                       |   0%
#
#
#
#
#
#
# unicodedata2-15.0.0  | 486 KB    |                                       |   0%
#
#
#
#
#
#
#
# graphviz-2.50.0      | 2.4 MB    |                                       |   0%
#
#
#
#
#
#
#
#
# font-ttf-source-code | 684 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
# libbrotlienc-1.0.9   | 303 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
# lcms2-2.15           | 222 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
# python_abi-3.10      | 4 KB      |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# tenacity-8.2.2       | 22 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
# font-ttf-dejavu-sans | 388 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# graphite2-1.3.14     | 82 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libbrotlidec-1.0.9   | 33 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openssl-1.1.1t       | 1.7 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# fonts-conda-forge-1  | 4 KB      |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# expat-2.5.0          | 118 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gdk-pixbuf-2.42.10   | 580 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# matplotlib-base-3.5. | 7.4 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# plotly-5.14.1        | 4.9 MB    |                                       |   0%
#  ... (more hidden) ...
#
#
#
# gettext-0.21.0       | 3.0 MB    | 7                                     |   2%
#
#
# lz4-c-1.9.4          | 153 KB    | ###8                                  |  10%
#
# giflib-5.2.1         | 75 KB     | #######9                              |  21%
# giflib-5.2.1         | 75 KB     | ##################################### | 100%
#
# ca-certificates-2022 | 142 KB    | ##################################### | 100%
#
#
# lz4-c-1.9.4          | 153 KB    | ##################################### | 100%
#
#
#
#
#
# munkres-1.1.4        | 12 KB     | ##################################### | 100%
#
#
#
#
#
# munkres-1.1.4        | 12 KB     | ##################################### | 100%
#
#
#
# gettext-0.21.0       | 3.0 MB    | ##########5                           |  28%
# freetype-2.10.4      | 890 KB    | ################6                     |  45%
#
#
#
#
#
#
# unicodedata2-15.0.0  | 486 KB    | #2                                    |   3%
#
#
#
# gettext-0.21.0       | 3.0 MB    | ################2                     |  44%
#
#
#
#
#
#
# unicodedata2-15.0.0  | 486 KB    | ####8                                 |  13%
# freetype-2.10.4      | 890 KB    | ##########################6           |  72%
#
#
#
#
# libgd-2.3.3          | 221 KB    | ##6                                   |   7%
#
#
#
#
# libgd-2.3.3          | 221 KB    | ##################################### | 100%
#
#
#
#
#
#
# unicodedata2-15.0.0  | 486 KB    | ##################################### | 100%
#
#
#
# gettext-0.21.0       | 3.0 MB    | #################################     |  89%
#
#
#
#
#
#
#
#
# font-ttf-source-code | 684 KB    | 8                                     |   2%
#
#
#
#
#
#
#
#
#
# libbrotlienc-1.0.9   | 303 KB    | #9                                    |   5%
#
#
#
#
#
#
#
# graphviz-2.50.0      | 2.4 MB    | 2                                     |   1%
# freetype-2.10.4      | 890 KB    | ##################################### | 100%
# freetype-2.10.4      | 890 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
# lcms2-2.15           | 222 KB    | ##6                                   |   7%
#
#
#
#
#
#
#
#
#
#
#
#
# tenacity-8.2.2       | 22 KB     | ###########################           |  73%
#
#
#
#
#
#
#
#
#
# libbrotlienc-1.0.9   | 303 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# tenacity-8.2.2       | 22 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
# lcms2-2.15           | 222 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libbrotlidec-1.0.9   | 33 KB     | ##################1                   |  49%
#
#
#
#
#
#
#
#
#
#
#
#
#
# font-ttf-dejavu-sans | 388 KB    | #5                                    |   4%
#
#
#
#
#
#
#
# graphviz-2.50.0      | 2.4 MB    | ##9                                   |   8%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libbrotlidec-1.0.9   | 33 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
# font-ttf-source-code | 684 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
# font-ttf-source-code | 684 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# python_abi-3.10      | 4 KB      | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openssl-1.1.1t       | 1.7 MB    | 3                                     |   1%
#
#
#
#
#
#
#
#
#
#
#
# python_abi-3.10      | 4 KB      | ##################################### | 100%
#
#
#
# gettext-0.21.0       | 3.0 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# graphite2-1.3.14     | 82 KB     | #######2                              |  20%
#
#
#
#
#
#
#
#
#
#
#
#
#
# font-ttf-dejavu-sans | 388 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# fonts-conda-forge-1  | 4 KB      | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# fonts-conda-forge-1  | 4 KB      | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# expat-2.5.0          | 118 KB    | #####                                 |  14%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# graphite2-1.3.14     | 82 KB     | ##################################### | 100%
#
#
#
#
#
#
#
# graphviz-2.50.0      | 2.4 MB    | ##############2                       |  39%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openssl-1.1.1t       | 1.7 MB    | ########################6             |  67%
#
#
#
#
#
#
#
# graphviz-2.50.0      | 2.4 MB    | ##########################7           |  72%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# expat-2.5.0          | 118 KB    | ###################################2  |  95%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# expat-2.5.0          | 118 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# matplotlib-base-3.5. | 7.4 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# plotly-5.14.1        | 4.9 MB    | 1                                     |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gdk-pixbuf-2.42.10   | 580 KB    | #                                     |   3%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# openssl-1.1.1t       | 1.7 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# matplotlib-base-3.5. | 7.4 MB    | ##########9                           |  30%
#
#
#
#
#
#
#
# graphviz-2.50.0      | 2.4 MB    | ##################################### | 100%
#
#
#
#
#
#
#
# graphviz-2.50.0      | 2.4 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# plotly-5.14.1        | 4.9 MB    | #6                                    |   5%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gdk-pixbuf-2.42.10   | 580 KB    | ###########2                          |  30%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# matplotlib-base-3.5. | 7.4 MB    | #####################2                |  58%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# plotly-5.14.1        | 4.9 MB    | ##7                                   |   7%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gdk-pixbuf-2.42.10   | 580 KB    | ####################4                 |  55%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# plotly-5.14.1        | 4.9 MB    | ####4                                 |  12%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# matplotlib-base-3.5. | 7.4 MB    | ############################1         |  76%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gdk-pixbuf-2.42.10   | 580 KB    | ###########################5          |  74%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# plotly-5.14.1        | 4.9 MB    | #######6                              |  21%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gdk-pixbuf-2.42.10   | 580 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gdk-pixbuf-2.42.10   | 580 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# plotly-5.14.1        | 4.9 MB    | #############                         |  35%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# plotly-5.14.1        | 4.9 MB    | ################                      |  43%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# plotly-5.14.1        | 4.9 MB    | ##################9                   |  51%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# plotly-5.14.1        | 4.9 MB    | #######################3              |  63%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# plotly-5.14.1        | 4.9 MB    | ###########################3          |  74%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# matplotlib-base-3.5. | 7.4 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# matplotlib-base-3.5. | 7.4 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# plotly-5.14.1        | 4.9 MB    | ###############################6      |  86%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# plotly-5.14.1        | 4.9 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# plotly-5.14.1        | 4.9 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
! conda install -c conda-forge lightgbm --yes
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Users/austinpaxton/anaconda3/envs/ML_bootcamp
#
#   added / updated specs:
#     - lightgbm
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     lightgbm-3.3.5             |  py310h879db79_0         1.1 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         1.1 MB
#
# The following NEW packages will be INSTALLED:
#
#   lightgbm           conda-forge/osx-64::lightgbm-3.3.5-py310h879db79_0
#
#
#
# Downloading and Extracting Packages
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %% [markdown]
# Your task in this optional section of the mini project is to read the documentation of these three libraries, and apply all of them to the "German Credit" dataset, just like you did in the case of Decision Trees and Random Forests.

# %% [markdown]
# The final deliverable of this section should be a table (can be a pandas DataFrame) which shows the accuracy of all the five algorthms taught in this mini project in one place.

# %% [markdown]
# Happy modeling! :)

# %%
# test xgboost
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score

model = XGBClassifier()
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
predictions = [round(value) for value in y_pred]  #XGBoost outputs probabilities not predictions 
# round probabilities to convert to binary predictions
xgboost_accuracy = accuracy_score(y_test, predictions)
print(xgboost_accuracy)
# Out:
# [19:54:31] WARNING: ../src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# 0
# 977:	learn: 0.2157211	total: 1.11s	remaining: 25.1ms
# 978:	learn: 0.2155577	total: 1.12s	remaining: 23.9ms
# 979:	learn: 0.2153430	total: 1.12s	remaining: 22.8ms
# 980:	learn: 0.2152081	total: 1.12s	remaining: 21.7ms
# 981:	learn: 0.2150669	total: 1.12s	remaining: 20.5ms
# 982:	learn: 0.2148591	total: 1.12s	remaining: 19.4ms
# 983:	learn: 0.2146139	total: 1.12s	remaining: 18.2ms
# 984:	learn: 0.2144051	total: 1.12s	remaining: 17.1ms
# 985:	learn: 0.2142491	total: 1.12s	remaining: 16ms
# 986:	learn: 0.2141355	total: 1.12s	remaining: 14.8ms
# 987:	learn: 0.2139886	total: 1.13s	remaining: 13.7ms
# 988:	learn: 0.2138406	total: 1.13s	remaining: 12.5ms
# 989:	learn: 0.2136318	total: 1.13s	remaining: 11.4ms
# 990:	learn: 0.2134708	total: 1.13s	remaining: 10.3ms
# 991:	learn: 0.2132702	total: 1.13s	remaining: 9.12ms
# 992:	learn: 0.2130093	total: 1.13s	remaining: 7.98ms
# 993:	learn: 0.2127417	total: 1.13s	remaining: 6.84ms
# 994:	learn: 0.2125986	total: 1.13s	remaining: 5.7ms
# 995:	learn: 0.2124431	total: 1.14s	remaining: 4.56ms
# 996:	learn: 0.2122746	total: 1.14s	remaining: 3.42ms
# 997:	learn: 0.2120071	total: 1.14s	remaining: 2.28ms
# 998:	learn: 0.2118138	total: 1.14s	remaining: 1.14ms
# 999:	learn: 0.2115593	total: 1.14s	remaining: 0us
# 0.8166666666666667

# %%
#test lightgbm
import lightgbm as lgb


train_data = lgb.Dataset(X_train,feature_name = list(X_train.columns), label= y_train)

params = {"num_leaves": 31,
         "num_trees": 100,
         "objective": "binary",
         "metric": "accuracy"
         }
model = lgb.train(train_set=train_data, params=params)
y_pred =  model.predict(X_test) #outputs probability -> convert to bianry pred

y_pred = [round(probability) for probability in y_pred]

lgb_score = accuracy_score(y_test,y_pred)
print(lgb_score)
# Out:
# /Users/austinpaxton/anaconda3/envs/ML_bootcamp/lib/python3.10/site-packages/lightgbm/engine.py:177: UserWarning: Found `num_trees` in params. Will use it instead of argument
# [LightGBM] [Info] Number of positive: 483, number of negative: 217
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000968 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 417
# [LightGBM] [Info] Number of data points in the train set: 700, number of used features: 54
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.690000 -> initscore=0.800119
# [LightGBM] [Info] Start training from score 0.800119
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# 0.7933333333333333

# %%
scores_dict = {
    "catboost": catboost_accuracy,
    "XGBoost": xgboost_accuracy,
    "RandomForest": rfc_accuracy,
    "Tree": tree_accuracy,
    "LightGBM": lgb_score
}
print(scores_dict)
scores_df = pd.DataFrame(scores_dict, index=[0])
display(scores_df)
# Out:
# {'catboost': 0.8166666666666667, 'XGBoost': 0.8033333333333333, 'RandomForest': 0.7966666666666666, 'Tree': 0.7133333333333334, 'LightGBM': 0.7933333333333333}
#    catboost   XGBoost  RandomForest      Tree  LightGBM
# 0  0.816667  0.803333      0.796667  0.713333  0.793333

# %% [markdown]
# Catboost is the best boosting algorithm for the german credit set data... Catboost, XGBoost, and LightGBM outperformed random forest and trees out of the box without parameter tuning.
